# %%
# Import du CSV
import pandas as pd

csv_path = "C:/Users/ASUS/Documents/Cours_epsi_2025/entrepot_données/Atelier1_Infra/data/2024_LoL_esports_match_data_from_OraclesElixir.csv"
df_raw = pd.read_csv(csv_path)

display(df_raw.head())
print("Nombre de lignes :", len(df_raw))
print("Nombre de colonnes :", df_raw.shape[1])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7564\623239730.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv(csv_path)
#                gameid datacompleteness  \
# 0  10660-10660_game_1          partial
# 1  10660-10660_game_1          partial
# 2  10660-10660_game_1          partial
# 3  10660-10660_game_1          partial
# 4  10660-10660_game_1          partial
#
#                                             url league  year split  playoffs  \
# 0  https://lpl.qq.com/es/stats.shtml?bmid=10660   DCup  2023   NaN         0
# 1  https://lpl.qq.com/es/stats.shtml?bmid=10660   DCup  2023   NaN         0
# 2  https://lpl.qq.com/es/stats.shtml?bmid=10660   DCup  2023   NaN         0
# 3  https://lpl.qq.com/es/stats.shtml?bmid=10660   DCup  2023   NaN         0
# 4  https://lpl.qq.com/es/stats.shtml?bmid=10660   DCup  2023   NaN         0
#
# ...

# %%
# Charger dans Mysql
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:root@localhost:3310/lol_raw_db")

df_raw.to_sql("lol_raw", engine, if_exists="replace", index=False)

print("Table lol_raw chargée dans MySQL")
# Out:
# Table lol_raw chargée dans MySQL
